# %% [markdown]
# ## Credentials
# Para fazer um request para o PAPI do youtube

# %%
from googleapiclient.discovery import build
#credential from my first project

youTubeApiKey_tres='Coloque_aqui_sua_chave'
youtube_tres=build('youtube','v3',developerKey=youTubeApiKey_tres)

# %% [markdown]
# ## Carregando o ambiente
#
# Pacotes habituais

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Obtendo dados de um video

# %%
request = youtube.videos().list(
          part="id, snippet, contentDetails, player, recordingDetails, statistics, status, topicDetails",
          id='wxvduBB8jPo'
      )
# fileDetails ,, ,suggestions,
response = request.execute()

# %% [markdown]
# "The request is not properly authorized to access video file or processing information. Note that the <code>fileDetails</code>, <code>processingDetails</code>, and <code>suggestions</code> parts are only available to that video's owner.">

# %%
response
# Out:
# {'etag': '16yqSZUHmDCXJPjIERM9rBuE37A',
#  'items': [{'contentDetails': {'caption': 'false',
#     'contentRating': {},
#     'definition': 'hd',
#     'dimension': '2d',
#     'duration': 'PT1H11M42S',
#     'licensedContent': True,
#     'projection': 'rectangular'},
#    'etag': 'HPzQUUtiHOvHmhtiaCgrPbewN7c',
#    'id': 'wxvduBB8jPo',
#    'kind': 'youtube#video',
#    'player': {'embedHtml': '<iframe width="480" height="270" src="//www.youtube.com/embed/wxvduBB8jPo" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'},
#    'recordingDetails': {},
#    'snippet': {'categoryId': '24',
#     'channelId': 'UCJBBmUckDiqitomUK7dEQzA',
#     'channelTitle': 'Canal Trece Colombia',
#     'defaultAudioLanguage': 'es-419',
#     'defaultLanguage': 'es',
# ...

# %% [markdown]
# ## Obtendo os videos mais populares de Brazil

# %% [markdown]
# request = youtube.videos().list(
#         part="snippet,contentDetails,statistics",
#         chart="mostPopular",
#         regionCode="US"
#     )
#     response = request.execute()

# %% [markdown]
# Pidiendo apenanas 50, dados tomados as

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        chart="mostPopular",
         maxResults=50,
        regionCode="BR"     
    )
response = request.execute()
response
# Out:
# {'etag': 'sNcX4jOeoXeFcRVkTNIhqoqmY-U',
#  'items': [{'contentDetails': {'caption': 'false',
#     'contentRating': {},
#     'definition': 'hd',
#     'dimension': '2d',
#     'duration': 'PT1M53S',
#     'licensedContent': True,
#     'projection': 'rectangular'},
#    'etag': 'u8_CeGGwunD0QMWrCO4eIkQLE08',
#    'id': 'TAgbP6WDa0c',
#    'kind': 'youtube#video',
#    'snippet': {'categoryId': '17',
#     'channelId': 'UCFHE5FRBeksxt7YoFPGeKPw',
#     'channelTitle': 'CONMEBOL Sudamericana',
#     'defaultAudioLanguage': 'pt',
#     'description': '#ceará \n#saopaulofc \n#sudamericana \n\nInscreva-se no canal oficial da CONMEBOL Sudamericana para ter acesso ao melhor conteúdo: https://bit.ly/30ZJAuZ\n\nEncontre todas as informações da competição no nosso site oficial:  https://conmebolsudamericana.com/\n\nSiga-nos nas redes sociais:\n\nTwitter: https://twitter.com/sulamericana\nInstagram: https://instagram.com/sulamericana\nFacebook: https://www.facebook.com/copasudamericana/',
# ...

# %% [markdown]
# #### Tornandolos data Frame

# %%
list_of_videos=response['items']
#len(list_of_videos)
#list_of_videos[0]

# %%
videos_id=[list_of_videos[i]['id'] for i in range(len(list_of_videos))]
videos_id
# Out:
# ['TAgbP6WDa0c',
#  'b9myf4WV2nY',
#  'KNgdwntgwQA',
#  'zi0wegeQ5Q4',
#  'FTjGUy7v0vo',
#  'v57ArxwpoE0',
#  'Vz4Sb1bl1IE',
#  'zZEpU-DbzZU',
#  'cjdlYdsKyI8',
#  '5g2hT4GmAGU',
#  'mzy0NaB3UKg',
#  's-EyKDmra3g',
#  '_--Z-DS7kF0',
#  'hhOhrbJR4Rc',
#  '13ge8mFP2cw',
#  'z2g_ket_CAo',
#  'lHllfbS2n3M',
#  'ehSXGv4bwDc',
#  'e2HZCdEOSs8',
#  'pIVx_neP-qk',
#  'XGZZFrz7P4U',
#  'tNpOc90esTE',
#  'eg99OVQJapA',
#  'fR3EoqTXdC0',
#  'Naw1jKYys_c',
#  'HuUWKZe6HPU',
#  'JAcIbGIAAvY',
#  'CWVdd7Qgsqs',
#  'dtFz2Vg6T14',
#  '8eYtGcbBkU4',
#  'MWDD-yMzYSU',
#  'Zv-xC5lMcWE',
#  'vacDXRqAWzc',
#  'gyTfjqt7jyE',
#  'u-RwXCzLtTM',
#  'w7pQ-O53tTA',
#  'XsBtzTniT_U',
#  'BVhFr4EVz70',
#  'Xqz1nHZqNgg',
#  'zBq1-TvRSVI',
#  'sb3AmA0V_YQ',
#  '2ZAYNUKiikY',
#  'x5rmJygBb6Y',
#  '1z4B-va-xhQ',
#  'XArXasD_v-Q',
#  '-t41pecfJa8',
#  'v0ZBw2y2rLw',
#  '5UdoUmvu_n8',
#  'rRBqH8s2XlQ',
#  'eiivVhYJ34o']

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        chart="mostPopular",
         maxResults=10,
        regionCode="BR"     
    )
response1 = request.execute()
response1
# Out:
# {'etag': 'IuZZuIz55OAgaBwMTcg9Sqx7YbM',
#  'items': [{'contentDetails': {'caption': 'false',
#     'contentRating': {},
#     'definition': 'hd',
#     'dimension': '2d',
#     'duration': 'PT2M39S',
#     'licensedContent': True,
#     'projection': 'rectangular'},
#    'etag': '1NtiG9dCyxFGpu7HN5aWxqalPAQ',
#    'id': 'ZSk2Fg9MTxI',
#    'kind': 'youtube#video',
#    'snippet': {'categoryId': '17',
#     'channelId': 'UCFHE5FRBeksxt7YoFPGeKPw',
#     'channelTitle': 'CONMEBOL Sudamericana',
#     'defaultAudioLanguage': 'pt',
#     'description': '#internacional \n#melgar \n#sudamericana \n\nInscreva-se no canal oficial da CONMEBOL Sudamericana para ter acesso ao melhor conteúdo: https://bit.ly/30ZJAuZ\n\nEncontre todas as informações da competição no nosso site oficial:  https://conmebolsudamericana.com/\n\nSiga-nos nas redes sociais:\n\nTwitter: https://twitter.com/sulamericana\nInstagram: https://instagram.com/sulamericana\nFacebook: https://www.facebook.com/copasudamericana/',
# ...

# %%
list1_of_videos=response1['items']
#len(list_of_videos)
#list_of_videos[0]

# %%
videos2_id=[list1_of_videos[i]['id'] for i in range(len(list1_of_videos))]
videos2_id
# Out:
# ['ZSk2Fg9MTxI',
#  '-PJF2k0kURI',
#  'Gz9VvcqTWzA',
#  'FcA3Zp65h3E',
#  'TAgbP6WDa0c',
#  'uT_G-ZQgY48',
#  'b9myf4WV2nY',
#  'fFiXY-lzd-U',
#  '9fS9O6-t3Rw',
#  'rJHZNU0kLXw']

# %%
videos1_id=[list1_of_videos[i]['id'] for i in range(len(list1_of_videos))]
videos1_id
# Out:
# ['TAgbP6WDa0c',
#  'b9myf4WV2nY',
#  'KNgdwntgwQA',
#  'zi0wegeQ5Q4',
#  'FTjGUy7v0vo',
#  'v57ArxwpoE0',
#  'Vz4Sb1bl1IE',
#  'zZEpU-DbzZU',
#  'cjdlYdsKyI8',
#  '5g2hT4GmAGU']

# %%
videos_id[:10]
# Out:
# ['TAgbP6WDa0c',
#  'b9myf4WV2nY',
#  'KNgdwntgwQA',
#  'zi0wegeQ5Q4',
#  'FTjGUy7v0vo',
#  'v57ArxwpoE0',
#  'Vz4Sb1bl1IE',
#  'zZEpU-DbzZU',
#  'cjdlYdsKyI8',
#  '5g2hT4GmAGU']

# %% [markdown]
# ## Obtendo dados de uma lista

# %% [markdown]
# Agora vamos puxar dados de youtube

# %%
# Extraindo videos de uma Playlist 
playlistId = 'PL9aaSAxVCc6h9HoDc222pPjg28QHWIJtD' #Dicas de Pandas Playlist
playlistName = 'Art et Culture'
nextPage_token = None

# %%
playlist_videos = []
res = youtube.playlistItems().list(part='snippet', playlistId = playlistId, maxResults=25).execute()
#maxResults=25 sei que tem 19 videos
playlist_videos=res['items']
len(playlist_videos)
# Out:
# 19

# %% [markdown]
# Na lista playlistvideos em cad entrada á um json, no qual contem diversas  informações como o título, de mais

# %%
print(playlist_videos[0])
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'RXeVZqkZnWdbrfuDDl5xYI8x_SQ', 'id': 'UEw5YWFTQXhWQ2M2aDlIb0RjMjIycFBqZzI4UUhXSUp0RC4yMUQyQTQzMjRDNzMyQTMy', 'snippet': {'publishedAt': '2022-05-18T13:01:26Z', 'channelId': 'UCftkAUwCOQM_FhQ4216qFhA', 'title': 'La vie de Claude Monet - Compréhension orale en français natif avec sous-titres.', 'description': 'Découvrez dans cet épisode pourquoi Claude Monet était l’un des peintres français les plus célèbres et l’un des meilleurs. Comment il a inventé son propre mouvement, l’impressionnisme...\n\nAméliore ta compréhension orale du français en écoutant du français compréhensible pour débutants, intérmédiaires ou avancés. \nBienvenue dans le podcast Fluidité. Histoire, géographie ou culture de France,  astuces pour apprender à parler avec confiance,...\n💡Active les sous-titres disponibles en français, anglais, espagnol et portugais.\n\n✅  La transcription gratuite en FRANCAIS : https://podcast.lefranchute.com/la-vie-de-claude-monet-episode-92/  \n
# ...

# %% [markdown]
# Em caso de uma playlist com muitos videos, poderiamos usar

# %%
playlist_videos = []

while True:
  res = youtube.playlistItems().list(part='snippet', playlistId = playlistId, maxResults=25, pageToken=nextPage_token).execute()
  playlist_videos += res['items']
  
  nextPage_token = res.get('nestPageToken')#atualiza a variavel nestPage_token

  if nextPage_token is None:
    break

# %%
  playlist_videos
# Out:
# [{'etag': 'RXeVZqkZnWdbrfuDDl5xYI8x_SQ',
#   'id': 'UEw5YWFTQXhWQ2M2aDlIb0RjMjIycFBqZzI4UUhXSUp0RC4yMUQyQTQzMjRDNzMyQTMy',
#   'kind': 'youtube#playlistItem',
#   'snippet': {'channelId': 'UCftkAUwCOQM_FhQ4216qFhA',
#    'channelTitle': 'Français avec Fluidité',
# ...

# %% [markdown]
# Capturando os videos ID dos 19 videos

# %%
videos_ids = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))

# %%
videos_ids
# Out:
# ['_wtHawS6xuc',
#  'BamKCNQ9a1U',
#  'T9M643o7MEc',
#  'Zz_Bf3vxIKc',
#  'NsgSFmXkv6Q',
#  'yTEjIYwpCM0',
#  'o1Z66BHlWQY',
#  '4ojAlSlWMKc',
#  'qjK1BVq5e_A',
#  '2CIdBk_ARx4',
#  'i9Um2GuQ-Es',
#  'bB1ljCN_gHo',
#  'RNgGD8WRBf0',
#  'eE55ihRqK18',
#  'EVIs1m1Ml9g',
#  'AmZd14IlM6g',
#  '8MXlPencrWM',
#  'icSHv9tX5UA',
#  'IoirD6FAR4Y']

# %% [markdown]
# Confirmaando que vieram todos os videos

# %%
len(videos_ids)
# Out:
# 19

# %%
stats = []

for video_id in videos_ids:
  res = youtube.videos().list(part='statistics', id=video_id, maxResults=25).execute() #endpoin list
  stats += res['items']

# %%
stats
# Out:
# [{'etag': 'ATHGfY-yHtyFuKKwTp_yC8r13Bc',
#   'id': '_wtHawS6xuc',
#   'kind': 'youtube#video',
#   'statistics': {'commentCount': '30',
#    'favoriteCount': '0',
#    'likeCount': '226',
#    'viewCount': '2142'}},
#  {'etag': '5ot6bUT9aqz-VHH9LjPLMwLwwnY',
#   'id': 'BamKCNQ9a1U',
#   'kind': 'youtube#video',
#   'statistics': {'commentCount': '14',
#    'favoriteCount': '0',
#    'likeCount': '233',
#    'viewCount': '2135'}},
#  {'etag': 'kFvEZ35Eki5vSuLOrQ6Or5vFuZo',
#   'id': 'T9M643o7MEc',
#   'kind': 'youtube#video',
#   'statistics': {'commentCount': '36',
#    'favoriteCount': '0',
#    'likeCount': '276',
#    'viewCount': '3590'}},
#  {'etag': 'L_isB7mHEbEGMwV0M65SjjJtuAs',
#   'id': 'Zz_Bf3vxIKc',
#   'kind': 'youtube#video',
#   'statistics': {'commentCount': '26',
#    'favoriteCount': '0',
#    'likeCount': '146',
#    'viewCount': '2170'}},
#  {'etag': 'FQEcdSxoUZUrvPHtx9gHcMchGjs',
#   'id': 'NsgSFmXkv6Q',
#   'kind': 'youtube#video',
# ...

# %%
videos_title = list(map(lambda x: x['snippet']['title'], playlist_videos))
#url_thumbnails = list(map(lambda x: x['snippet']['thumbnails']['high']['url'], playlist_videos))
published_date = list(map(lambda x: str(x['snippet']['publishedAt']), playlist_videos)) #conversion from ISO8601 date format
video_description = list(map(lambda x: x['snippet']['description'], playlist_videos))
videoid = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))

# %%
liked = list(map(lambda x: int(x['statistics']['likeCount']), stats))
#disliked = list(map(lambda x: int(x['statistics']['dislikeCount']), stats))
views = list(map(lambda x: int(x['statistics']['viewCount']), stats))
comment = list(map(lambda x: int(x['statistics']['commentCount']), stats))

# %% [markdown]
# Verificando os comprimentos, das listas geradas

# %%
atributos=['videos_title','published_date','video_description','videoid','liked','views','comment']

for i in atributos:
  print('Lista',i,'tem',len(i))
# Out:
# Lista videos_title tem 12
# Lista published_date tem 14
# Lista video_description tem 17
# Lista videoid tem 7
# Lista liked tem 5
# Lista views tem 5
# Lista comment tem 7

# %%
from datetime import datetime 

extraction_date = [str(datetime.now())]*len(videos_ids)

# %%
import pandas as pd
playlist_df = pd.DataFrame({'title':videos_title,
      'video_id':videoid,
      'video_description':video_description,
      'published_date':published_date,
      'extraction_date':extraction_date,
      'likes':liked,
      'views':views,
      'comment':comment})
playlist_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-490fd66ce825> in <module>()
#       6       'extraction_date':extraction_date,
#       7       'likes':liked,
# ----> 8       'views':views})
#       9 playlist_df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# ...

# %% [markdown]
# ## Obtendo dados de um canal

# %%
from googleapiclient.discovery import build
youTubeApiKey='Coloque_aqui_sua_chave'
youtube=build('youtube','v3',developerKey=youTubeApiKey)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Canal  do Pietro Guedes que é o promeiro video tendência que aparece;

# %%
chanel_id='UCGfBwrCoi9ZJjKiUK8MmJNw'

# %%
request = youtube.channels().list(
          part="snippet,contentDetails,statistics",
          id=chanel_id
      )
response = request.execute()

# %%
response
# Out:
# {'etag': 'lqulcFV5qR5mM5460st_Ca6eqGA',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUGfBwrCoi9ZJjKiUK8MmJNw'}},
#    'etag': 'rVGZblwUFrRWFTp0wiR1qjD9y04',
#    'id': 'UCGfBwrCoi9ZJjKiUK8MmJNw',
#    'kind': 'youtube#channel',
#    'snippet': {'country': 'BR',
#     'description': 'Salve rapaziada!',
#     'localized': {'description': 'Salve rapaziada!', 'title': 'Pietro Guedes'},
#     'publishedAt': '2013-06-20T23:16:31Z',
#     'thumbnails': {'default': {'height': 88,
#       'url': 'https://yt3.ggpht.com/ytc/AKedOLQmK5q51J-9JEboRPV3ORMqmPjvv9dsp7DYbrgGtw=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88},
#      'high': {'height': 800,
#       'url': 'https://yt3.ggpht.com/ytc/AKedOLQmK5q51J-9JEboRPV3ORMqmPjvv9dsp7DYbrgGtw=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800},
#      'medium': {'height': 240,
#       'url': 'https://yt3.ggpht.com/ytc/AKedOLQmK5q51J-9JEboRPV3ORMqmPjvv9dsp7DYbrgGtw=s240-c-k-c0x00ffffff-no-rj',
# ...

# %% [markdown]
# Usando os métodos do objeto youue, podemos fazer reques para comunicarnos diretamente co m a API do youtube

# %%
def get_chanel_stats(youtube,channel_id):
  
  request = youtube.channels().list(
          part="snippet,contentDetails,statistics",
          id=channel_id
      )
  response = request.execute()
  data=dict(Nome_Do_Canal=response['items'][0]['snippet']['title'],Subcriptores=str(response['items'][0]['statistics']['subscriberCount']),
            Vistas=response['items'][0]['statistics']['viewCount'],Total_Videos=response['items'][0]['statistics']['videoCount'],
            playlist_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads'])

  return(data)

# %%
get_chanel_stats(youtube,chanel_id)
# Out:
# {'Nome_Do_Canal': 'Pietro Guedes',
#  'Subcriptores': '1030000',
#  'Total_Videos': '119',
#  'Vistas': '70455768',
#  'playlist_id': 'UUGfBwrCoi9ZJjKiUK8MmJNw'}

# %%
canal_stats=get_chanel_stats(youtube,chanel_id)

# %% [markdown]
# ## Obtendo os dados de todos os canais, que foram tendência

# %% [markdown]
# A ideia de esta seção é extrair mais atributos relevantes dos canais que posicionaram, com a finalidade de agregar os seguintes atributos associados com o **canal** que consideramos sejam importantes no momento de determinar probabilidade de um determinado vídeo ser tendencia:
#
# 1. Numero se subscriptores;
# 2. data de criação;
# 3. Número total de vídeos postados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link='/content/drive/MyDrive/MyCopy/You_tube_database/archive/'

# %%
dados_original = pd.read_csv(link+'tendencias_tratadas.csv',lineterminator='\n')
dados_original.drop(columns='Unnamed: 0')
dados_original.head(2)
# Out:
#    Unnamed: 0           Id                                          Titulo  \
# 0           0  s9FH4rDMvds  LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1           1  jbGRowa5tIk                       ITZY “Not Shy” M/V TEASER
#
#                         Data                      C_id           C_titulo  \
# 0  2020-08-11 22:21:49+00:00  UCGfBwrCoi9ZJjKiUK8MmJNw      Pietro Guedes
# 1  2020-08-11 15:00:13+00:00  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#         Categoria             Data_tendencia  \
# 0  People & Blogs  2020-08-12 00:00:00+00:00
# 1           Music  2020-08-12 00:00:00+00:00
#
#                                             Etiqueta   Vistas   likes  \
# 0  pietro|guedes|ingrid|ohara|pingrid|vlog|amigos...   263835   85095
# 1  JYP Entertainment|JYP|ITZY|있지|ITZY Video|ITZY ...  6000070  714310
#
#    dislikes  Q_comentarios                                          Descricao
# 0       487           4500  Salve rapaziada, neste vídeo me declarei pra e...
# ...

# %%
dados=dados_original.copy()

# %%
dados.tail(2)
# Out:
#         Unnamed: 0           Id                                     Titulo  \
# 154566      154589  TUtpUoletXQ            KATERINI GANHOU MUITA COISA!!!!
# 154567      154590  1MCZM4PP5J4  Race Highlights | 2022 Italian Grand Prix
#
#                              Data                      C_id        C_titulo  \
# 154566  2022-09-11 22:06:46+00:00  UCk-X1li7YXeIdrqZSTT-x4g  Dora Rodrigues
# 154567  2022-09-11 15:38:18+00:00  UCB_qr75-ydFVKSF9Dmo6izg       FORMULA 1
#
#              Categoria             Data_tendencia  \
# 154566  People & Blogs  2022-09-19 00:00:00+00:00
# 154567          Sports  2022-09-19 00:00:00+00:00
#
#                                                  Etiqueta   Vistas   likes  \
# 154566  Dora Rodrigues|maternidade|maternity|bebê|baby...   149178   19189
# 154567  F1|Formula One|Formula 1|Sports|Sport|Action|G...  5370501  105532
#
#         dislikes  Q_comentarios  \
# 154566         0            529
# 154567         0           6551
#
# ...

# %%
dados=dados.drop(columns='Unnamed: 0')
dados.head(2)
# Out:
#             Id                                          Titulo  \
# 0  s9FH4rDMvds  LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1  jbGRowa5tIk                       ITZY “Not Shy” M/V TEASER
#
#                         Data                      C_id           C_titulo  \
# 0  2020-08-11 22:21:49+00:00  UCGfBwrCoi9ZJjKiUK8MmJNw      Pietro Guedes
# 1  2020-08-11 15:00:13+00:00  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#         Categoria             Data_tendencia  \
# 0  People & Blogs  2020-08-12 00:00:00+00:00
# 1           Music  2020-08-12 00:00:00+00:00
#
#                                             Etiqueta   Vistas   likes  \
# 0  pietro|guedes|ingrid|ohara|pingrid|vlog|amigos...   263835   85095
# 1  JYP Entertainment|JYP|ITZY|있지|ITZY Video|ITZY ...  6000070  714310
#
#    dislikes  Q_comentarios                                          Descricao
# 0       487           4500  Salve rapaziada, neste vídeo me declarei pra e...
# ...

# %% [markdown]
# Guardando numa lista todos os canales que saim

# %%
chanels_ids=dados['C_id'].unique()

# %%
len(chanels_ids)
# Out:
# 4382

# %% [markdown]
# Testemos a construção de um data frame comdados dos primeiros 10 canais

# %%
chanels_10=chanels_ids[:25]

# %% [markdown]
# Temos um canal conflitivo

# %%
chanels_ids[23]
# Out:
# 'UCh71DB0DGAjl1xIVrJysR3w'

# %%
request = youtube_tres.channels().list(
          part="snippet,contentDetails,statistics",
          id='UCh71DB0DGAjl1xIVrJysR3w'
      )
response = request.execute()
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'ZDQLxw6dCZ3ubnp3x3TfsWTXrJ0',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '_0ZpIw9pzMaRtJ4rONe1dql1bis',
#    'id': 'UCh71DB0DGAjl1xIVrJysR3w',
#    'snippet': {'title': 'IRMÃS MADAME!',
#     'description': '',
#     'publishedAt': '2017-11-08T18:09:06Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu-JuejViJ0bpsLlmXqAKVRgdlDoBh6wcBKBqeK8=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu-JuejViJ0bpsLlmXqAKVRgdlDoBh6wcBKBqeK8=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu-JuejViJ0bpsLlmXqAKVRgdlDoBh6wcBKBqeK8=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'IRMÃS MADAME!', 'description': ''}},
# ...

# %% [markdown]
# Note que não temos subscriber count, precesamos agregar exepciones nestes casos.

# %%
def get_chanel_statistics(channel_id):
  request = youtube_tres.channels().list(
          part="snippet,contentDetails,statistics",
          id=channel_id
      )
  response = request.execute()
  
  return(response)

# %%
def constru_data_frame_from_dicts(lista):
  aux=[]    
  for i in lista:
    aux.append(get_chanel_statistics(i))

  df = pd.DataFrame(aux)
  
  return(df)

# %% [markdown]
# Fazemos a requisição de todos a

# %%
chanels_tendencia_BR=constru_data_frame_from_dicts(chanels_ids)
chanels_tendencia_BR.head()
# Out:
#                           kind                         etag  \
# 0  youtube#channelListResponse  sLIwplK0uthJBImH3gVaySt11MA
# 1  youtube#channelListResponse  QURbk4OozvoCqlUJ3_xPb2_cfsk
# 2  youtube#channelListResponse  JY9UGCBI1rPMH6_ye4Nzv_0669k
# 3  youtube#channelListResponse  qFoCc0TOVtoaG9gG6gS13WNOozw
# 4  youtube#channelListResponse  4uPr8rOHYqaQ64Y6HPpEaDKzK50
#
#                                    pageInfo  \
# 0  {'totalResults': 1, 'resultsPerPage': 5}
# 1  {'totalResults': 1, 'resultsPerPage': 5}
# 2  {'totalResults': 1, 'resultsPerPage': 5}
# 3  {'totalResults': 1, 'resultsPerPage': 5}
# 4  {'totalResults': 1, 'resultsPerPage': 5}
#
#                                                items
# 0  [{'kind': 'youtube#channel', 'etag': '2fkA8dQm...
# 1  [{'kind': 'youtube#channel', 'etag': 'Rspjxk8A...
# 2  [{'kind': 'youtube#channel', 'etag': 'aYUyhSSX...
# 3  [{'kind': 'youtube#channel', 'etag': 'TXGjb_5_...
# 4  [{'kind': 'youtube#channel', 'etag': 'YZNPKgRT...

# %%
dados_novos=chanels_tendencia_BR.copy()

# %%
dados_novos
# Out:
#                              kind                         etag  \
# 0     youtube#channelListResponse  sLIwplK0uthJBImH3gVaySt11MA
# 1     youtube#channelListResponse  QURbk4OozvoCqlUJ3_xPb2_cfsk
# 2     youtube#channelListResponse  JY9UGCBI1rPMH6_ye4Nzv_0669k
# 3     youtube#channelListResponse  qFoCc0TOVtoaG9gG6gS13WNOozw
# 4     youtube#channelListResponse  4uPr8rOHYqaQ64Y6HPpEaDKzK50
# ...                           ...                          ...
# 4377  youtube#channelListResponse  cXkpCO7r6XigzJO_cmtMHaNCUjY
# 4378  youtube#channelListResponse  K5qqHvrQ7qzkga2Ktz8RiIkLQx8
# 4379  youtube#channelListResponse  WwSu7bQyGO01PnfKRzALu8qpRts
# 4380  youtube#channelListResponse  j8QzSRqJa5ddbdrHdy0vOFp3pRI
# 4381  youtube#channelListResponse  tKQZti33xrhlpDeg1jOEdU_d0j0
#
#                                       pageInfo  \
# 0     {'totalResults': 1, 'resultsPerPage': 5}
# 1     {'totalResults': 1, 'resultsPerPage': 5}
# 2     {'totalResults': 1, 'resultsPerPage': 5}
# ...

# %%
chanels_tendencia_BR.shape[0]
# Out:
# 4382

# %%
chanels_tendencia_BR['items'][191]
# Out:
# nan

# %% [markdown]
# Quando o API, nao consegue trazer os "items" de um canal ela retorna nan, preenchemos esses valores com [], assim nao darao erro

# %%
from ast import literal_eval
chanels_tendencia_BR['items']=chanels_tendencia_BR['items'].fillna('[]')

# %% [markdown]
# Como todos os dadtos items sao listas de u elemento, todos tem [0], ou seja sao iteraveis

# %%
dados_novos=chanels_tendencia_BR.copy()

# %%
dados_novos['items']=dados_novos['items'].apply(lambda x:x[0])

# %% [markdown]
# **Usamos** normalize, para criar novas colunas a partir de um diccionario que estaba contido numa coluna,ele desmenbra esta coluna criando  atributos com  as chaves do diccionario e os valores sao os registros qe entram nas linhas

# %%
pd_normalize=pd.json_normalize(dados_novos['items'])

# %%
pd_normalize
# Out:
#                  kind                         etag                        id  \
# 0     youtube#channel  2fkA8dQmwFTuREN4Ip0ghTkbiJ0  UCGfBwrCoi9ZJjKiUK8MmJNw
# 1     youtube#channel  Rspjxk8A24wIo7Ku2ycRfd-0wwU  UCaO6TYtlC8U5ttz62hTrZgg
# 2     youtube#channel  aYUyhSSXQxakrr8QVze0GU2ZPEI  UCoXZmVma073v5G1cW82UKkA
# 3     youtube#channel  TXGjb_5_QhdY0zNDbduJ7SSw5og  UC6Xqz2pm50gDCORYztqhDpg
# 4     youtube#channel  YZNPKgRT0gd1g_qxsroJgNc8HAM  UCEWOoncsrmirqnFqxer9lmA
# ...               ...                          ...                       ...
# 4377  youtube#channel  zAasM3LJpOGDTHoJ2yJ5r2ZfMyQ  UCQIP8lTtl3BrWbPdTYpST4Q
# 4378  youtube#channel  XHzewOtSjVRhunmD2Jb7oBrv51E  UC6ZImLwiIaVRYIGycqh5iLA
# 4379  youtube#channel  XEZOeb6_S3n3UalwQcfiy7dXNsI  UCsli20tlTA9tW73P5gyBMzg
# 4380  youtube#channel  OlQz3AMzXTyfsi6iArTNXR3dcgo  UCYDZsRrVuSdf3HCfpAokjGA
# 4381  youtube#channel  ozMCvgl3LhIRWqg0WZPFxscml9c  UCj8uD4DVd0wqBglLWSx4Kdw
#
#                      snippet.title  \
# ...

# %% [markdown]
# pd_normalize

# %%
df1=pd_normalize[['id','snippet.title','snippet.description','snippet.publishedAt',
                  'snippet.country','statistics.viewCount',
                 'statistics.subscriberCount','statistics.videoCount',]]

# %%
df1.rename(columns = {'id':'C_id','snippet.title':'C_Titulo', 'snippet.description':'C_Descricao',
                        'snippet.publishedAt':'C_Data',
                        'snippet.country':'C_Pais','statistics.viewCount':'C_vistas',
                        'statistics.subscriberCount':'Subscriptores',
                       'statistics.videoCount':'No Videos'}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1.head()
# Out:
#                        C_id                      C_Titulo  \
# 0  UCGfBwrCoi9ZJjKiUK8MmJNw                 Pietro Guedes
# 1  UCaO6TYtlC8U5ttz62hTrZgg             JYP Entertainment
# 2  UCoXZmVma073v5G1cW82UKkA                 As Irmãs Mota
# 3  UC6Xqz2pm50gDCORYztqhDpg      League of Legends Brasil
# 4  UCEWOoncsrmirqnFqxer9lmA  The Noite com Danilo Gentili
#
#                                          C_Descricao  \
# 0                                   Salve rapaziada!
# 1  JYPnation Official YouTube\n\nLEADER IN ENTERT...
# 2  Oi galerinha linda!!! 😊😍❤ \nSomos a Núbia e a ...
# 3
# 4  O The Noite com Danilo Gentili traz muitos ent...
#
#                         C_Data C_Pais     C_vistas Subscriptores No Videos
# 0         2013-06-20T23:16:31Z     BR     82549250       1070000       122
# 1         2008-01-25T07:45:44Z    NaN  17668290822      25700000      1553
# 2  2020-02-09T19:12:48.805452Z     BR    340301630       1030000       109
# ...

# %% [markdown]
# Guardamos os dados já tratados, para ter eles disponíveis posteriormente

# %%
df1['C_Data']= pd.to_datetime(df1['C_Data'])
df1['C_vistas']= pd.to_numeric(df1['C_vistas'],errors='coerce',downcast='integer')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1['No Videos']= pd.to_numeric(df1['No Videos'],errors='coerce',downcast='integer')
df1['Subscriptores']= pd.to_numeric(df1['Subscriptores'],errors='coerce',downcast='integer')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1.dtypes
# Out:
# C_id                          object
# C_Titulo                      object
# C_Descricao                   object
# C_Data           datetime64[ns, UTC]
# C_Pais                        object
# C_vistas                     float64
# Subscriptores                float64
# No Videos                    float64
# dtype: object

# %%
link
# Out:
# '/content/drive/MyDrive/MyCopy/You_tube_database/archive/'

# %%
df1.head(2)
# Out:
#                        C_id           C_Titulo  \
# 0  UCGfBwrCoi9ZJjKiUK8MmJNw      Pietro Guedes
# 1  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#                                          C_Descricao  \
# 0                                   Salve rapaziada!
# 1  JYPnation Official YouTube\n\nLEADER IN ENTERT...
#
#                      C_Data C_Pais      C_vistas  Subscriptores  No Videos
# 0 2013-06-20 23:16:31+00:00     BR  8.254925e+07      1070000.0      122.0
# 1 2008-01-25 07:45:44+00:00    NaN  1.766829e+10     25700000.0     1553.0

# %%
with open(link+'Canais_Tendencia.csv', 'w') as f:
  df1.to_csv(f)

# %% [markdown]
# O método pd_normalize toma um ditcionario e cria colunas para cada ua das chaves, colocados os valores das filas como o valores do diccionario

# %% [markdown]
# Usamos um dicionario para renomear as colunas para a lingua portuguesa

# %% [markdown]
# ## Todos os videos de um canal
#
# ### Function to get the functiuons ID

# %%
def get_video_ids(youtube,playlist_id):
  playlist_videos = []
  nextPage_token = None

  while True:
    res = youtube.playlistItems().list(part='snippet', playlistId = canal_data, maxResults=25, pageToken=nextPage_token).execute()
    playlist_videos += res['items']
    
    nextPage_token = res.get('nestPageToken')#atualiza a variavel nestPage_token

    if nextPage_token is None:
      break

# %% [markdown]
# ## Procurando videos relacionados
#
# Para uma documentação ao respeito do uso do YouTUbe API e amostragem de videos veja
#
#
# https://developers.google.com/youtube/v3/docs/search/list
#
#
# ### Procurando videos baseandose em palavra chave

# %%
def bring_videos_base_on_key(youtube,keyword):

  request = youtube.search().list(
          part='snippet',
          maxResults=1,# default 5
          regionCode='BR',
          #The regionCode parameter instructs the API to return search results 
          #for videos that can be viewed in the specified country. 
          type='video',
          order='viewCount',
          q=keyword
      )
  response = request.execute()

  return(response)

# %%
bring_videos_base_on_key(youtube,'dogs')
# Out:
# {'etag': 'ObL5NxGcSlTZqZ0Q5i-6FPnSm0Y',
#  'items': [{'etag': 'r9bys7hJtgNm4B-JoD9xgC7qNYM',
#    'id': {'kind': 'youtube#video', 'videoId': '07d2dXHYb94'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCaZX9C1LPOpzsJfZe5BxDjw',
#     'channelTitle': 'Southeastern Guide Dogs',
#     'description': "Dog's heroics will make you cry! Donate at https://www.guidedogs.org/pip Click here for the audio description for the visually ...",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-10-24T20:00:14Z',
#     'publishedAt': '2018-10-24T20:00:14Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/07d2dXHYb94/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/07d2dXHYb94/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/07d2dXHYb94/mqdefault.jpg',
#       'width': 320}},
# ...

# %% [markdown]
# Neste query me retorna, uma lista de tamanho ajustavel , baseado numa palavra chave, arbitraria, as palavras de interesse poderiam ser tomadas das tags, ou do título fdos videos.

# %% [markdown]
# ### Procurando videos baseandose em video id

# %%
def bring_videos_base_on_id(youtube,videoId):

  request = youtube.search().list(
          part='snippet',
          maxResults=2,# default 5
          regionCode='BR', # Visível desde Brasil
          relatedToVideoId=videoId,
          #The regionCode parameter instructs the API to return search results
          #for videos that can be viewed in the specified country. 
          type='video',
          #order='rating'
      )
  response = request.execute()

  return(response)

# %%
bring_videos_base_on_id(youtube,'npoUGx7UW7o')
# Out:
# {'etag': 'fIsTPY0WODB-QluSD6geBIF00iw',
#  'items': [{'etag': '7feqXMOCa9Q0kH9OqMyqx89rdxM',
#    'id': {'kind': 'youtube#video', 'videoId': '7kRBQfye7e0'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCEWOoncsrmirqnFqxer9lmA',
#     'channelTitle': 'The Noite com Danilo Gentili',
#     'description': 'Danilo conversa com seus amigos do Ultraje a Rigor, que estão comemorando seus 35 anos de banda.\n\nVeja mais em http://www.sbt.com.br/thenoite/\n\nInscreva-se no canal do The Noite: http://www.youtube.com/sbtthenoite\n\nCurta a página do programa no Facebook:\nhttps://www.facebook.com/SBTTheNoite\n\nSiga o perfil oficial do programa no Twitter:\nhttps://twitter.com/SBTTheNoite',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2016-11-22T16:11:38Z',
#     'publishedAt': '2016-11-22T16:11:38Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/7kRBQfye7e0/default.jpg',
#       'width': 120},
# ...

# %% [markdown]
# ### Videos tendência
#
# Podemos extrairos videos mais populares por pais e por categoria
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Experimento de evolução de views

# %% [markdown]
# Vamos registrar a evolução das estatisticas dinamicas de um video.
#
# Para isso, vamos analisar só as que são variáveis no tempo:
#
# - Viewcount;
# -Comment count
#
# Selecionamos um video popular do dia

# %%
request = youtube.videos().list(
          part="statistics",
          id='UHaomXFyYZU'
      )
# fileDetails ,, ,suggestions,
response = request.execute()
response
# Out:
# {'etag': 'NYtVt1QCUzO5PMPPDSrFwuq3DtI',
#  'items': [{'etag': 'hhaxRLQ6gxjmpW05KIFZMAbEo0M',
#    'id': 'UHaomXFyYZU',
#    'kind': 'youtube#video',
#    'statistics': {'commentCount': '706',
#     'favoriteCount': '0',
#     'likeCount': '6265',
#     'viewCount': '91374'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %% [markdown]
# Estes dados correspondem com o dia 8 de julho às 15:30

# %%
request = youtube.videos().list(
          part="statistics",
          id='UHaomXFyYZU'
      )
# fileDetails ,, ,suggestions,
respons1 = request.execute()
respons1
# Out:
# {'etag': 'dxqf_cGYaBx8rbxhepNwq45c8Bg',
#  'items': [{'etag': 'PIct0iVRrZUVR2fqMCKR6Exvs80',
#    'id': 'UHaomXFyYZU',
#    'kind': 'youtube#video',
#    'statistics': {'commentCount': '723',
#     'favoriteCount': '0',
#     'likeCount': '6421',
#     'viewCount': '94469'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %% [markdown]
# Estes dados correspondem com o dia 8 de julho às 15:30

# %%
request = youtube.videos().list(
          part="statistics",
          id='UHaomXFyYZU'
      )
# fileDetails ,, ,suggestions,
respons2 = request.execute()
respons2
# Out:
# {'etag': '5UxuZj5Z9ejJZQ8awLLTEEcUIh0',
#  'items': [{'etag': 'gbAfSH2eHpqA9d9fmrd2YjNNgNU',
#    'id': 'UHaomXFyYZU',
#    'kind': 'youtube#video',
#    'statistics': {'commentCount': '749',
#     'favoriteCount': '0',
#     'likeCount': '6569',
#     'viewCount': '97220'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %% [markdown]
# ## Obtendo os videos mais populares de Brazil

# %% [markdown]
# request = youtube.videos().list(
#         part="snippet,contentDetails,statistics",
#         chart="mostPopular",
#         regionCode="US"
#     )
#     response = request.execute()

# %% [markdown]
# ## Criando o atributo de duração do vídeo
#
# Nesta parte vamos agregar o atributo comprimento à base de dados, que é um atrinuto que não estaba originalmente mas que acreditamos que impata nas probabilidades de um vídeo virar ou não tendência.
#
# Para isso precissamos ter a lista completa de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

import numpy as np

link='/content/drive/MyDrive/python/You_tube_database/archive/'

# %%
tendencias=pd.read_csv(link+'tendencias_tratadas.csv',lineterminator='\n')

tendencias.shape

tendencias.sample(2)

tendencias=tendencias.drop(columns='Unnamed: 0')
tendencias.sample(1)
# Out:
#                  Id                          Titulo  \
# 136578  NqEbyq4Q8Qs  O Filme do Shrek no Minecraft!
#
#                              Data                      C_id  C_titulo  \
# 136578  2022-06-21 13:05:13+00:00  UCrcBZDofBltcgGxphNia2tw  Problems
#
#        Categoria             Data_tendencia Etiqueta   Vistas  likes  \
# 136578     Music  2022-06-22 00:00:00+00:00   [None]  1071193  50663
#
#         dislikes  Q_comentarios  \
# 136578         0           1581
#
#                                                 Descricao  Duracao
# 136578  Eu Recriei o Filme do Shrek no Minecraft!Eu Re...    869.0

# %% [markdown]
# Uma vez carregados os dados  vamos obter uma lista dos ids diferentes na base de dados

# %%
ids=list(tendencias['Id'].unique())


len(ids)
# Out:
# 23581

# %% [markdown]
# Faremos uma requisição pedindo todas as durações dos videos,
#
# para esto precisamos ter acceso a uma chave do Google

# %%
from googleapiclient.discovery import build


#credential from my first project

youTubeApiKey_tres='AIzaSyATFvXhnex-GUZt1kyoCHo-io1PL-REM-c'
youtube_tres=build('youtube','v3',developerKey=youTubeApiKey_tres)

# %% [markdown]
# A part snippet contem a categoria, e  content details contem a dura??o dos v?deos .

# %%
i=0
durations=[]

for i in range(100):
  request = youtube_tres.videos().list(
            part="contentDetails",
            id=ids[50*i:(i+1)*50]
        )
  # fileDetails ,, ,suggestions,
  response = request.execute()
  durations+=response['items']


i=0
for i in range(100,200):
  request = youtube_tres.videos().list(
            part="contentDetails",
            id=ids[50*i:(i+1)*50]
        )
  # fileDetails ,, ,suggestions,
  response = request.execute()
  durations+=response['items']

durations_save=durations.copy()

i=0
for i in range(200,300):
  request = youtube_tres.videos().list(
            part="contentDetails",
            id=ids[50*i:(i+1)*50]
        )
  # fileDetails ,, ,suggestions,
  response = request.execute()
  durations+=response['items']

i=0
for i in range(300,400):
  request = youtube_tres.videos().list(
            part="contentDetails",
            id=ids[50*i:(i+1)*50]
        )
  # fileDetails ,, ,suggestions,
  response = request.execute()
  durations+=response['items']

i=0
for i in range(400*50,len(ids)):
  request = youtube_tres.videos().list(
            part="contentDetails",
            id=ids[i]
        )
  # fileDetails ,, ,suggestions,
  response = request.execute()
  durations+=response['items']

len(durations)
# Out:
# 22852

# %% [markdown]
# Note que não conseguimos a duração de todos os vídeos da base de dados

# %% [markdown]
# Convertemos as durações num data frame

# %%
d={'items':durations}
df=pd.DataFrame(d)
pd_normalize=pd.json_normalize(df['items'])
pd_normalize=pd_normalize[['id','contentDetails.duration']]
pd_normalize.rename(columns={'contentDetails.duration':'Duracao'},inplace=True)
pd_normalize.head(1)

#PT4H30M30S
# Out:
#             id  Duracao
# 0  s9FH4rDMvds  PT10M4S

# %% [markdown]
# Guardamos uma copia por segurança

# %%
df_copy=pd_normalize.copy()

# %% [markdown]
# E vamos guardar eles num documento csv, caso sejam detetadas falhas no tratamento de dados

# %%
link='/home/brayan/GoogleDrive/python/You_tube_database/archive/'

# %%
with open(link+'durations_non_format.csv', 'w') as f:
  pd_normalize.to_csv(f)

# %% [markdown]
# **C<omeçando desde aqui**

# %%
pd_normalize=pd.read_csv(link+'durations_non_format.csv')
pd_normalize=pd_normalize.drop(columns='Unnamed: 0')
pd_normalize.head(6)
# Out:
#             id     Duracao
# 0  s9FH4rDMvds     PT10M4S
# 1  jbGRowa5tIk       PT21S
# 2  3EfkCrXKZNs      PT3M5S
# 3  npoUGx7UW7o    PT31M18S
# 4  Vu6PNpYKu2U    PT18M15S
# 5  ly8jXKq_9AE  PT3H36M26S

# %%
df_copy=pd_normalize.copy()

# %%
pd_normalize.dtypes
# Out:
# id         object
# Duracao    object
# dtype: object

# %% [markdown]
# O objetivo é ter  uma varivel duração como uma variável numérica, no formato de estring no qual esta atualmente, não encontrei uma forma direta de converter em número, note que a mínima unidade são os segundos, farei uma função para transformar estes strings na quantidade de segundos, usarei a estruturs regular PT##H##M##S para converter os strings

# %%
import re

# %% [markdown]
# Usando a função re.split posso indicar quais caracteres pode eliminar

# %%
a=re.split('[h-t]+','PT1H10M4S', flags=re.IGNORECASE)
a
# Out:
# ['', '1', '']

# %% [markdown]
# Do jeido quee estamos dividindo sempre, vai ter as virgolas, isto poderia ser simplesmente acrescentado, uma condição ao regex, mas preferimos eliminarlo da lista, já que as posições das virgolas nesta lista sempre serão na primeira e última posição.
#
#
# Fazemos isto e convertimos para inteiros os números restante

# %%
a=a[1:-1]
a=[int(i) for i in a]
a
# Out:
# [1]

# %%
a[0]*60+a[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-550804502344> in <module>
# ----> 1 a[0]*60+a[1]
#
# IndexError: list index out of range

# %%
time='3H'
a=re.split('S',time, flags=re.IGNORECASE)
print('string a',a)
b=re.split('M',str(a[0]))
print('string b',b,len(b))
c=re.split('H',str(b[0]))
print('string c',c,len(c))
# Out:
# string a ['3H']
# string b ['3H'] 1
# string c ['3', ''] 2

# %%
def sugundos(palavra):
    segundos=0
    a=re.split('S',time, flags=re.IGNORECASE)

# %%
 def to_segundos(time):   
    # re.split('[f-u]+',time, flags=re.IGNORECASE)
    minutos=0
    segundos=0
    horas=0
    a=re.split('PT',time, flags=re.IGNORECASE)
    b=re.split('S',str(a[-1]))
    if len(b)==2:
        # print('HÁ SEGUNDOS')
        c=re.split('M',str(b[0]))

        if len(c)==2:
            segundos=int(c[-1])  
            # print('HÁ MINUTOS')

            d=re.split('H',str(c[0]))

            if len(d)==2:
                # print('HÁ HORAS')
                minutos=int(d[-1])*60      
                horas=int(d[-2])*3600
            else:
                # print('NÃO HORAS')
                minutos=int(d[0])*60         
                horas=0
        else:
            # print('NÃO HÁ MINUTOS')

            minutos=0
            d=re.split('H',str(c[0]))
            if len(d)==2:
                # print('HÁ HORAS')
                segundos=int(d[-1])  

                horas=int(d[-2])*3600
            else:
                # print('NÃO HÁ HORAS')
                segundos=int(b[0])  
                horas=0
    else:

        # print(' NÃO HA SEGUNDOS')

        seguindos=0
        c=re.split('M',str(b[0]))
        if len(c)==2:

            # print(' HÁ MINUTOS  ')

            d=re.split('H',str(c[0]))

            if len(d)==2:
                # print('HÁ HORAS')
                minutos=int(d[-1])*60
                horas=int(d[-2])*3600
            else:
                # print('NÃO HÁ HORAS')
                minutos=int(d[0])*60       
                horas=0
        else:
            # print('NÃO HÁ MINUTOS ')              

            minutos=0
            d=re.split('H',str(c[0]))

            if len(d)==2:
                # print('HÁ HORAS')    

                horas=int(d[-2])*3600
            else:
                # prin('NÃO HÁ HORAS')

                horas=0
    total=horas+minutos+segundos

    return total

# %%
to_segundos('PT10H10M10S')
# Out:
# 36610

# %% [markdown]
# Colocando agora isto numa função, que simuaneamente converta o strint para lista, e a lusta para segundos

# %%
def dura_to_segun(time):
  segundos=0
  import re 
  a=re.split('[f-u]+',time, flags=re.IGNORECASE)
  a=a[1:-1]
  a=[int(i) for i in a]
  if len(a)==2:
    segundos=a[0]*60+a[1]
  elif len(a)==3:
    segundos=a[2]+60*(a[1]+a[0]*60)
  else:
    segundos=a[0]
  
  return segundos

# %%
dura_to_segun('PT10M4S')
# Out:
# 604

# %%
dura_to_segun('PT4H30M30S')
# Out:
# 16230

# %% [markdown]
# Agora aplicaremos esta função á coluna durations

# %%
# Duracoes=[df_copy['Duracao'][i] for i in range(len(df_copy))]
# Duracoes

# %%
Duracoes_seg=[dura_to_segun(i) for i in Duracoes]

# %%
df_copy['Duracao']=df_copy['Duracao'].apply(to_segundos)

# %%
df_copy.dtypes
# Out:
# id         object
# Duracao     int64
# dtype: object

# %%
len(df_copy[df_copy['Duracao']<=30])
# Out:
# 1090

# %%
df_copy.isna().sum()
# Out:
# id         0
# Duracao    0
# dtype: int64

# %%
df_copy.head(2)
# Out:
#             id  Duracao
# 0  s9FH4rDMvds      604
# 1  jbGRowa5tIk       21

# %%
link
# Out:
# '/home/brayan/GoogleDrive/python/You_tube_database/archive/'

# %%
with open(link+'durations.csv', 'w') as f:
  df_copy.to_csv(f)

# %%
link='/content/drive/MyDrive/python/You_tube_database/archive/'

# %%
import pandas as pd
duration=pd.read_csv(link+'durations.csv')
duration=duration.drop(columns='Unnamed: 0')
duration
# Out:
#                 id  Duracao
# 0      s9FH4rDMvds      604
# 1      jbGRowa5tIk       21
# 2      3EfkCrXKZNs      185
# 3      npoUGx7UW7o     1878
# 4      Vu6PNpYKu2U     1095
# ...            ...      ...
# 22860  AfCZTJS65k4     1239
# 22861  vExtiIWz52o       49
# 22862  UYlAeI87Dsg      815
# 22863  8MBQDiaBsR8     1041
# 22864  SU8pHC9F3hE      589
#
# [22865 rows x 2 columns]

# %% [markdown]
# ## Segunda parte de anexar as durações
